# %% [markdown]
# ## [1. Matplotlib](https://matplotlib.org)
#
# ------

# %%
from IPython.display import IFrame
IFrame("figures/matplotlib_sheet.pdf", width=1000, height=800)
# Out:
#         <iframe
#             width="1000"
#             height="800"
#             src="figures/matplotlib_sheet.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ![](./figures/cheatsheets-1.png)
# ![](./figures/cheatsheets-2.png)
# ![](./figures/handout-beginner.png)
# ![](./figures/handout-intermediate.png)
# ![](./figures/handout-tips.png)
#
# -----

# %% [markdown]
# ## numpy
# ![](./figures/numpy_sheet.png)

# %% [markdown]
# ## pandas
# ![](./figures/pandas_basic.png)
# ![](./figures/Pandas_advanced.png)

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.distplot(tips['total_bill'])

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex') # kind = blank, reg, kde

# %%
sns.pairplot(tips,hue='sex') # hue -> categorical data

# %%
sns.rugplot(tips['total_bill'])

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker',split=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex')

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',split=True)
# Out:
# /home/guanqzha/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %%
sns.factorplot(x='day',y='total_bill',data=tips,kind='bar') #violin
# Out:
# /home/guanqzha/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
tc = tips.corr()

# %%
sns.heatmap(tc,annot=True)

# %%
fp = flights.pivot_table(index='month',columns='year',values='passengers')
sns.heatmap(fp,cmap='magma')

# %%
sns.clustermap(fp,cmap='coolwarm')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
#g.map_diag(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
g = sns.FacetGrid(data=tips,col='time',row='smoker')
g.map(sns.distplot,'total_bill')

# %%
sns.set_style('white')
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)
sns.despine()

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='seismic') #pallet is a colermap'seismic'

# %%
navy = sns.palplot(sns.light_palette("navy", reverse=True))

# %%
sns.palplot(sns.color_palette("Blues"))

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
sns.palplot(sns.color_palette(flatui))
